# %% [markdown]
# <a href="https://colab.research.google.com/github/ertugrulkirac/SSD-MobileNetV2-FPNLite-EdgeTPU/blob/main/multimodal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import shutil
import subprocess

print("=" * 70)
print("COLAB SYSTEM CHECK")
print("=" * 70)

print("\nGPU:")
subprocess.run(["nvidia-smi"])

print("\nDISK:")
total, used, free = shutil.disk_usage("/content")

print(f"Total : {total / 1024**3:.2f} GB")
print(f"Used  : {used / 1024**3:.2f} GB")
print(f"Free  : {free / 1024**3:.2f} GB")
# Out:
# ...
# COLAB SYSTEM CHECK
# ...
#
# GPU:
#
# DISK:
# Total : 235.68 GB
# Used  : 47.28 GB
# Free  : 188.38 GB
